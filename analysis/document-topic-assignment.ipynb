# %% [markdown]
# # Assigning Topics to Documents
#
# *This notebook computes topic models from documents and assigns the strongest topic to each document.*

# %%
import json
import nlp

dataset = 'asm' # lss/asm
input_file = '../data/lss-17k.json'
output_file = '../data/lss-17k-topics.json'

if dataset == 'asm':
    input_file = '../data/lss_asm_dataset.txt'
    output_file = '../data/lss-asm-topics.json'

# %% [markdown]
# ####  Load data

# %%
def load(filename):
    'A text file with each line as a JSON text.'
    p = parse_asm if dataset == 'asm' else parse_lss
    with open(filename) as file:
        sessions = [p(line) for line in file]
    return [s for s in sessions if s]

def parse_asm(text):
    'Return the list of actions from the given JSON text.'
    obj = json.loads(text)
    if 'actions' in obj and obj['actions'] and len(obj['actions']) <= 150: # limit max length to sync with the vis
        action = [a['name'][6:] for a in obj['actions']] #  [6:] to exclude the prefix 'Action'
        return { 'id': obj['session']['dcxID'], 'action': action }

def parse_lss(text):
    'Return the list of actions from the given JSON text.'
    obj = json.loads(text)
    if 'actionsQueue' in obj and obj['actionsQueue'] and obj['userId'] != 'none' and obj['officeId'] != 'none' and obj['orga'] != 'none':
        action = [a[6:] for a in obj['actionsQueue']] #  [6:] to exclude the prefix 'Action'
        return { 'id': obj['PFX'], 'action': action }

# %%
data = load(input_file)
docs = [d['action'] for d in data]
len(data), data[0]
# Out:
# (18957,
#  {'action': ['SearchUsr',
#    'SearchUsr',
#    'DisplayOneUser',
#    'UpdateUserDetails',
#    'TabBar',
#    'SearchUsr',
#    'DisplayOneUser',
#    'UpdateUserDetails',
#    'TabBar',
#    'TabBar'],
#   'id': '2LK1J5ID313Q1BWKN##NAGHU91'})

# %% [markdown]
# #### Compute topics with LDA

# %%
lda = nlp.build_lda(docs, num_topics=10)
lda.print_topics()
# Out:
# [(0,
#   '0.341*"DisplayOneUser" + 0.137*"CloseTab" + 0.128*"CreateLoginArea" + 0.120*"AddNewLoginArea" + 0.092*"UpdateUserDetails" + 0.042*"NotifyDisplayedUser" + 0.031*"EditLoginArea" + 0.025*"DeleteLoginArea" + 0.023*"UpdateLogAreaIndic" + 0.019*"ResetPwdDisplayed"'),
#  (1,
#   '0.205*"ChooseOrganization" + 0.198*"FilterByApp" + 0.181*"FilterByAppACL" + 0.179*"DisplayOneUser" + 0.041*"AuthenticationHistorySearch" + 0.031*"Cancel" + 0.026*"FilterUser" + 0.022*"DuplicateToExistingUser1" + 0.022*"DuplicateToUsrConfirmation" + 0.018*"DuplicateToExistingUser"'),
#  (2,
#   '0.182*"CloseTab" + 0.148*"DisplayOneAppli" + 0.124*"UnLockUser" + 0.075*"ManageAppRole" + 0.055*"FilterRolesForApp" + 0.030*"FilterPermissionforApp" + 0.030*"Cancel" + 0.021*"CreateRole" + 0.020*"CreateRole2" + 0.019*"SaveAddRemovePermissions"'),
#  (3,
#   '0.197*"TpfRefreshTable" + 0.114*"FilterHistory" + 0.061*"TpfMassImport" + 0.061*"CreateAclForRole" + 0.061*"DisplayOneAppli" + 0.055*"CreateAclForRole2" + 0.046*"AddDataToACL" + 0.044*"SearchACLForApp" + 0.035*"EnterCreateData" + 0.034*"LinkCreateACLForRole"'),
#  (4,
#   '0.219*"CreateUser" + 0.151*"WarningDeleteUser" + 0.142*"CloseTab" + 0.124*"DeleteUser" + 0.109*"ResetPwdUnlock" + 0.068*"DuplicateUser" + 0.045*"CopyDisplayedUser" + 0.039*"UnLockUser" + 0.024*"DeleteDisplayedUser" + 0.021*"CopyUser"'),
#  (5,
#   '0.458*"Next" + 0.126*"Prev" + 0.110*"DisplayOneUser" + 0.100*"Cancel" + 0.055*"OneUserRoleDetails" + 0.025*"Last" + 0.021*"PopupAddNewAppSecuRule" + 0.018*"ValidateCreateTFARule" + 0.015*"CloseTab" + 0.012*"CancelTwo"'),
#  (6,
#   '0.291*"DisplayOrgaDetails" + 0.135*"AdminOguStep1" + 0.106*"RefreshReports" + 0.096*"AddOfficeDod" + 0.096*"AddOfficeDodFinish" + 0.069*"CloseTab" + 0.035*"ViewDetailsdod" + 0.030*"MoveOgu" + 0.016*"FilterOffices" + 0.015*"PopupEditDirectTFARule"'),
#  (7,
#   '0.135*"AssignAcl2" + 0.135*"AssignAcl1" + 0.113*"AssignACLStep3" + 0.074*"AssignRoleAclConfirmation1" + 0.073*"SearchRoleForAssignRoleAcl" + 0.067*"DisplayOneUser" + 0.066*"CloseTab" + 0.059*"Cancel" + 0.055*"FilterAssignACLStep2" + 0.046*"RemoveACL"'),
#  (8,
#   '0.362*"SearchOffice" + 0.280*"CloseTab" + 0.264*"DisplayOneOffice" + 0.041*"DisplayOneUser" + 0.018*"DisplayOneOGU" + 0.008*"ViewAssignUserPref" + 0.007*"AssignUserPref" + 0.005*"UnLockUser" + 0.004*"FilterLoginArea" + 0.003*"SearchAvailableData"'),
#  (9,
#   '0.200*"AssignRole1" + 0.179*"AssignRole2" + 0.163*"AssignRoleAclConfirmation1" + 0.145*"CloseTab" + 0.136*"CreateUser" + 0.054*"DisplayOneUser" + 0.026*"SearchRoleForAssignRoleAcl" + 0.022*"RemoveOneUserRole" + 0.022*"NotifyDisplayedUser" + 0.014*"CreateDataButton"')]

# %% [markdown]
# #### Assign the strongest topic to each document

# %%
def assign_topic(data, docs, lda):
    'Return a lookup { id: topic }.'
    corpus = [lda.id2word.doc2bow(doc) for doc in docs]
    topic_ids = nlp.get_strongest_document_topics(lda, corpus)
    return { d['id']: topic_ids[i] for i, d in enumerate(data) }

# %%
output_data = assign_topic(data, docs, lda)
output_data
# Out:
# {'2LK1J5ID313Q1BWKN##NAGHU91': 0,
#  'Y3M5R#QBI$1G0#DZEARJDT4U91': 9,
#  'SRNGMVO$TI3F1X9JIKKMFPKU91': 8,
#  'LQBSP0BOWN1506W1HTEMVMEU91': 4,
#  '9F0E1SXEC6FU0S13CP8$MRJU91': 0,
#  'W6BJQ25L91PK1S76ZFRG$SNU91': 4,
#  'HW1AW$563S8F0XC9F63XMQ#T91': 0,
#  'U8X22ATF2FT108XJ$X2GZV1U91': 0,
#  'LN3SVSBR4V661WY8Y41C3W1U91': 2,
#  'ZGTIAU$826HA0V6EZJ59KGHU91': 0,
#  '7T06G8D697QI0NX8RG7ML8T7A0': 3,
#  'Y3MEU4X4UOKC1TKF#6P2WYLU91': 6,
#  'JG1F7MJ7WU6W1DCT2J1DDVFU91': 0,
#  'IT5XQ2H0RUFD1Q$3UK0GBQ#T91': 0,
#  '3#DTSGCRFD040T#K6JVYXMEU91': 0,
#  '$$QIF#VDXOTV1DCT2J1DDVFU91': 8,
#  'I8ZL0B$9MY9Q0BWKN##NAGHU91': 0,
#  'M0QY#PA81$WT0EQT5KFUBW1U91': 8,
#  '8P45VWBSIP8G1ZE3B2$E#KLU91': 0,
#  '$SHWEKMBB9QC0NX8RG7ML8T7A0': 8,
#  'A6S$8S6FSJ560NX8RG7ML8T7A0': 6,
#  'IHQRKV6HOWB314V2QRMJPIEY90': 9,
#  'QHAFCS76PHFO1NX8RG7ML8T7A0': 8,
#  '4A06$GD6ZS0J0NX8RG7ML8T7A0': 2,
#  '7DXF2UBZONPU04V2QRMJPIEY90': 2,
#  '3336WYM5118C1BWKN##NAGHU91': 0,
#  'JYQN35MQ5HHF1NX8RG7ML8T7A0': 2,
#  '9W3IBTH1ZXWD04V2QRMJPIEY90': 2,
#  'EYYIW2IG6MT$04V2QRMJPIEY90': 2,
#  'I0C7XW40SL0T1NX8RG7ML8T7A0': 9,
#  'S2FKJ$NRK58D1NX8RG7ML8T7A0': 3,
#  'BVSG8859BFXE1NX8RG7ML8T7A0': 2,
#  'JP6I54EGL47P14V2QRMJPIEY90': 2,
#  'HG4$RKUU8WHM1YXAVS6GYZ2U91': 0,
#  'J5DRV50HW$S90WY8Y41C3W1U91': 0,
#  'D4G2JT96HS#X0R5ZPVSMNS#T91': 0,
#  '6AB1#41NE2CJ1XC9F63XMQ#T91': 5,
#  '4D65V6JDA76W0BWKN##NAGHU91': 6,
#  'RQAZ6A8FA0VN1NX8RG7ML8T7A0': 0,
#  '4VQK57VBY15X0K0T5HBQA58U91': 0,
#  'HLZUKV5XW7CP1CC$FDT11E6U91': 0,
#  'CI4C5V#ZUOQ81OKNZBG03LLU91': 8,
#  'IFBRG#P$$AV016V2QRMJPIEY90': 0,
#  'BIA1QRBTV3$P06V2QRMJPIEY90': 0,
#  'F004EAWSC33W1M5FUFP5I$2U91': 0,
#  '$JDROZ$G6HM806VDR7NOG$2U91': 8,
#  '7FMWZT4GV5L#08XJ$X2GZV1U91': 6,
#  'J83N70BPQ26511HYC28LRT4U91': 0,
#  'GJCZ#IBYAQI004V2QRMJPIEY90': 9,
#  'TB1D5Y0FUQGX14V2QRMJPIEY90': 2,
#  'TSLNBWH$ZQP#04V2QRMJPIEY90': 9,
#  'AOE#QBCI9WVW04V2QRMJPIEY90': 8,
#  '#J8H9C265RHC14V2QRMJPIEY90': 3,
#  'CFVNB6CRAZVQ04V2QRMJPIEY90': 7,
#  'U742KHTG081Y04V2QRMJPIEY90': 1,
#  'U1JNIWDQCHF81NX8RG7ML8T7A0': 3,
#  '1NEPFF2D$XPY0NX8RG7ML8T7A0': 8,
#  'S9BGGR#E7MPS14V2QRMJPIEY90': 3,
#  '7FSR453UP7AZ14V2QRMJPIEY90': 2,
#  'LRAZF0WZGTQK04V2QRMJPIEY90': 2,
#  'OIWP#TRX#Z3M1NX8RG7ML8T7A0': 2,
#  'BFKX0W17R3AT04V2QRMJPIEY90': 2,
#  'XG5O$MN##MKQ1NX8RG7ML8T7A0': 2,
#  'NICMIX$DKV$70NX8RG7ML8T7A0': 6,
#  'K1VZ$WKV15V31NX8RG7ML8T7A0': 2,
#  '7G53DYGKVJW00NX8RG7ML8T7A0': 2,
#  'NM16G45A0M5L1NX8RG7ML8T7A0': 2,
#  'BS1AJ805GG8$0NX8RG7ML8T7A0': 0,
#  'R#A$CHQY1CKH04V2QRMJPIEY90': 6,
#  'H2G#F#YEJ5FT14V2QRMJPIEY90': 8,
#  'JJ7O0LEZ83JM0ZE3B2$E#KLU91': 0,
#  'F6B0C$TMBE321NX8RG7ML8T7A0': 0,
#  'B4VXTY7Q$5#11NX8RG7ML8T7A0': 0,
#  '82J8OYI5YNDX1#DZEARJDT4U91': 4,
#  '2DVCRPU#6Z3P1K0T5HBQA58U91': 4,
#  '#8TP5PQM33U#0NX8RG7ML8T7A0': 7,
#  'JJ039KGJDHD30KUS3JRJ8GFU91': 0,
#  'JVQT6V$2#9D60#DZEARJDT4U91': 0,
#  'YHFL76ZDN8UW0YXAVS6GYZ2U91': 5,
#  'D2E51RK7SHP20D2#9XYXOUEU91': 9,
#  '1#GRRJNZQFT60T#K6JVYXMEU91': 0,
#  'E4XO0XUZ4NVS09QRDFE7$58U91': 8,
#  '71DNS49OCB$20XC9F63XMQ#T91': 0,
#  'N#6RBF8SRN471YXAVS6GYZ2U91': 4,
#  'RIY$OUM8VZ$60BWKN##NAGHU91': 8,
#  'TQXLYLVP9F$50IITDIAPBUFU91': 0,
#  '1K82OEETAHJ#04V2QRMJPIEY90': 9,
#  'O9$C3D5WIM550NX8RG7ML8T7A0': 1,
#  '2#2943CIGPPK1V6EZJ59KGHU91': 4,
#  'LAOXUUZFN6J91K0T5HBQA58U91': 0,
#  'ICAM1BGS8VXI14V2QRMJPIEY90': 8,
#  'Z$AUFWHRU4SD0WY8Y41C3W1U91': 2,
#  'ACH5LBFX2F$11#DZEARJDT4U91': 8,
#  'NT0FGUYU14#G0DCT2J1DDVFU91': 0,
#  '3LWX121YOVXN1X82LV9YJRJU91': 0,
#  '6N988AVVHM$11ZE3B2$E#KLU91': 4,
#  'AOS3229JJ9TT1CC$FDT11E6U91': 0,
#  'B$VA#TKJ49QU0X9JIKKMFPKU91': 8,
#  'Q80W9ULEZH7E1XC9F63XMQ#T91': 4,
#  'Q1NIU3IUI8T509QRDFE7$58U91': 0,
#  '6F6QZH0GD8FU0#DZEARJDT4U91': 5,
#  'VF9V3IH5QCF70YATAP92TUEU91': 9,
#  'GP9LBI47ALDC1K0T5HBQA58U91': 0,
#  'I4HHETZT#A761NX8RG7ML8T7A0': 0,
#  'T4MEPZ137HTF1PX8RG7ML8T7A0': 2,
#  'WVD2LC3PDZ9H0NX8RG7ML8T7A0': 9,
#  'JUAKVQLYQRJD1NX8RG7ML8T7A0': 7,
#  '91R3#YMSSVHN1Q$3UK0GBQ#T91': 0,
#  'E0C5U3JT9VU40#71OYZ1XQJU91': 0,
#  'N9V6$5GQ8RVO14V2QRMJPIEY90': 7,
#  '9FSD1#N#W7V80V6EZJ59KGHU91': 0,
#  'JYEIAR8P1J3D1S13CP8$MRJU91': 0,
#  'ID0N2J14QHDO0ZE3B2$E#KLU91': 0,
#  'NZAJ5FMEVFXW06VDR7NOG$2U91': 8,
#  'RNFTQLICIP3L13AYHQV9168U91': 1,
#  'D4O3DMQQWIQ70K#S9M2BUGFU91': 0,
#  'YK2KYT3CSHH91X9JIKKMFPKU91': 8,
#  '0R3OUMZQ9UBU1S76ZFRG$SNU91': 0,
#  'ES0A$8Y4E7000Q$3UK0GBQ#T91': 8,
#  'YWHNV2YZ92JI16VDR7NOG$2U91': 7,
#  'NF2ISB$M784I1X9JIKKMFPKU91': 0,
#  '9Y96RYIPC3YX1IITDIAPBUFU91': 0,
#  'ZACKG2SHQO3W14V2QRMJPIEY90': 8,
#  'BQL2S6QSDRG514V2QRMJPIEY90': 1,
#  'A1NCJJ0KE6UG14V2QRMJPIEY90': 5,
#  '9X8B8D7R$LQS06VDR7NOG$2U91': 6,
#  'HEEUYY7SGE$00PX8RG7ML8T7A0': 5,
#  'DP7C6CNR2YBV0NX8RG7ML8T7A0': 9,
#  'FWZN$H0QI#IR16VDR7NOG$2U91': 8,
#  'OJTYYKRWV$BZ0PX8RG7ML8T7A0': 8,
#  'MM2TXOKRTY9V08XJ$X2GZV1U91': 2,
#  '4#BHLZ6FBSIR0NX8RG7ML8T7A0': 0,
#  'P$LF3QV$GVU10WY8Y41C3W1U91': 1,
#  'YUH8X5G7KPUA0NX8RG7ML8T7A0': 9,
#  'N#CAJQ1I1A3S06W1HTEMVMEU91': 7,
#  'J17AEIFZOASN0M5FUFP5I$2U91': 1,
#  'JI3HHTLR2ACL0NX8RG7ML8T7A0': 8,
#  '#MALLN#6XEM111VF8IQ3TT4U91': 3,
#  '83JX0L$K5INH1T#K6JVYXMEU91': 8,
#  'PS$3PMPB4CL61NX8RG7ML8T7A0': 6,
#  'WM2QTF1COGWG0NX8RG7ML8T7A0': 9,
#  '9SYP8#J6PPAO1NX8RG7ML8T7A0': 8,
#  'P1UKL4KGUBX31NX8RG7ML8T7A0': 7,
#  'MP#NM8X8TOAQ0NX8RG7ML8T7A0': 1,
#  '2NVG1MTZK35F14V2QRMJPIEY90': 8,
#  '86MO4YUL1R1Z14V2QRMJPIEY90': 4,
#  'IF1SXG12KAJV06W1HTEMVMEU91': 8,
#  'WG7L9KK390V604V2QRMJPIEY90': 9,
#  'NPE33XY35BCC0Q$3UK0GBQ#T91': 3,
#  'Q$6RPLRWIDPO1UV54AM9CPKU91': 0,
#  'P$1V9AUENQ191NX8RG7ML8T7A0': 6,
#  'KAHA53MZOY0M14V2QRMJPIEY90': 6,
#  'EFSVBT4EB51W1NX8RG7ML8T7A0': 2,
#  '6#M23W5K1#BI1NX8RG7ML8T7A0': 0,
#  'YOD#2JE3VQFS14V2QRMJPIEY90': 8,
#  'API3IQMDON#F1NX8RG7ML8T7A0': 0,
#  'E0L0$S0UGY8X04V2QRMJPIEY90': 3,
#  'UXSLMDC25VPT1UV54AM9CPKU91': 2,
#  '2E7Z89AMM#WU1YATAP92TUEU91': 0,
#  '5TKUL0ZU37QX0YATAP92TUEU91': 0,
#  'M6RWK7F8XEMG0NX8RG7ML8T7A0': 2,
#  '6C4XB1KMMXW206VDR7NOG$2U91': 2,
#  '2RJAQVDMG8#201HYC28LRT4U91': 8,
#  'AVSY1X0##F7I14V2QRMJPIEY90': 0,
#  'SN6RBC4DQTIB1NX8RG7ML8T7A0': 0,
#  'F#LZ23$5BXAB14V2QRMJPIEY90': 4,
#  'LE211FMYU0GL06VDR7NOG$2U91': 2,
#  '#OGM0SDL7TGR19QRDFE7$58U91': 0,
#  '8YR19JC4F8X70NX8RG7ML8T7A0': 0,
#  '8C3DV81C$$PW0NX8RG7ML8T7A0': 9,
#  'NEFH1RVU5XFF1S76ZFRG$SNU91': 2,
#  '7YJO0MGG#1GK1OKNZBG03LLU91': 0,
#  'QBY8VU1AZ8761NX8RG7ML8T7A0': 8,
#  'I6A7T7VT4RIX14V2QRMJPIEY90': 7,
#  '3QJ9A30G27CE14V2QRMJPIEY90': 8,
#  '5VCNPLDIZJLD14V2QRMJPIEY90': 6,
#  'KWTV6VM32MJK1NX8RG7ML8T7A0': 3,
#  'A6Q$9UZ6T63H0NX8RG7ML8T7A0': 2,
#  'CWV$PJEPO#L$04V2QRMJPIEY90': 9,
#  'K1WV03559#K$04V2QRMJPIEY90': 7,
#  'K1#BLWXO5R9W14V2QRMJPIEY90': 3,
#  '6HAP#93QP#3O08XJ$X2GZV1U91': 4,
#  'U9E93XME2NKA0NX8RG7ML8T7A0': 2,
#  '9SVCBNHOKPLF0VFRIZC#$T4U91': 0,
#  'DW98UV6X$5LR04V2QRMJPIEY90': 0,
#  '5FYUHW2YF8RQ04V2QRMJPIEY90': 0,
#  '7#P9BXONWK9M0V6EZJ59KGHU91': 2,
#  'KHQZ5OQG8KHZ1KUS3JRJ8GFU91': 2,
#  'YSQSJQO0LQQV0K#S9M2BUGFU91': 4,
#  'RCA2KW35$9HL0T#K6JVYXMEU91': 0,
#  'UN6F2WSGA#510KP1$OHE1B6U91': 4,
#  'XS8V6B093OA81TKF#6P2WYLU91': 0,
#  'VSRB1NL98$R31KUS3JRJ8GFU91': 0,
#  'OP5N05ACURB#0#DZEARJDT4U91': 9,
#  'RBK5K1KFN2SB04V2QRMJPIEY90': 0,
#  '0PAV77SFSTUM1V6EZJ59KGHU91': 0,
#  '5D$863WSYEHV1WY8Y41C3W1U91': 0,
#  'HDOO7ZA08T#Q1UV54AM9CPKU91': 8,
#  'D#2DOWIPDCAR1NX8RG7ML8T7A0': 7,
#  'AMTHT35BTP2C14V2QRMJPIEY90': 0,
#  'Q1RAOG4#YL9Q0YATAP92TUEU91': 8,
#  '353E61EEM#K61NX8RG7ML8T7A0': 9,
#  '33GSNER4S88Z0Q$3UK0GBQ#T91': 0,
#  'BJXFV$#6M6PB04V2QRMJPIEY90': 3,
#  'UVMG39$THEPU14V2QRMJPIEY90': 1,
#  'HT592DX#M1NC1NX8RG7ML8T7A0': 2,
#  'EJE8GL2TOO5Y04V2QRMJPIEY90': 2,
#  'RBGD84976EBT01HYC28LRT4U91': 0,
#  'ESWR5F6RU##214V2QRMJPIEY90': 8,
#  'HKKS3GJR7ZW001VF8IQ3TT4U91': 5,
#  'GJM5VG10DJJY0S76ZFRG$SNU91': 8,
#  'RVI2PZTQC05G1IITDIAPBUFU91': 9,
#  'D4RZLFZEOHA20M5FUFP5I$2U91': 0,
#  'RFATUT87VO8M1NX8RG7ML8T7A0': 8,
#  'EZ0OPF#UT31R1NX8RG7ML8T7A0': 3,
#  '#9N0K$XJ7WHF14V2QRMJPIEY90': 8,
#  '4CK$OA728O4L04V2QRMJPIEY90': 2,
#  '9OZGOQT7F3PX1NX8RG7ML8T7A0': 2,
#  '7ER1Q$#WH8UQ1NX8RG7ML8T7A0': 2,
#  'H0N2HYK4YWVX1WY8Y41C3W1U91': 0,
#  '#8WY52MVUJ$B0KUS3JRJ8GFU91': 0,
#  '$BGZ5RIC1ZL404V2QRMJPIEY90': 4,
#  'GT0VPLV4KHKM0NX8RG7ML8T7A0': 0,
#  'YS0#6H07SFMP06W1HTEMVMEU91': 6,
#  'AKCHCGU3RELF1EQT5KFUBW1U91': 4,
#  '6H4ACL2PBMT4014XGQACHC6U91': 7,
#  'Z4BU5I6IDUU906V2QRMJPIEY90': 7,
#  'I1BN52K7ZFG704V2QRMJPIEY90': 4,
#  'F0E63GWV#ZQP0XC9F63XMQ#T91': 6,
#  '6L5#V3PA2KPN1OKNZBG03LLU91': 8,
#  '$OUY$SZAKOYZ0YATAP92TUEU91': 6,
#  'P4WKDE$31L5F1XC9F63XMQ#T91': 4,
#  '3W81FEGXUWD919BJW8U4#SNU91': 6,
#  'FQS1KJPFMA540X82LV9YJRJU91': 2,
#  'JK20RFU7UN7Q04V2QRMJPIEY90': 0,
#  'DBFWSYJUC4SF06VDR7NOG$2U91': 9,
#  '6NOAPLC1YNSK0SS0YHV2URJU91': 4,
#  '4OA$C#0F7Q6O13AYHQV9168U91': 0,
#  'FDWK#2AT8J270EQT5KFUBW1U91': 0,
#  '$VUWWQO2ECEH14V2QRMJPIEY90': 9,
#  'A0UH64S$AKNC0NX8RG7ML8T7A0': 9,
#  'L91ZQ7JECQ6504V2QRMJPIEY90': 2,
#  '7F$M8R0TMFEL1ZE3B2$E#KLU91': 4,
#  'CT5353RPPX9N1NX8RG7ML8T7A0': 8,
#  'M7ZX098#5PBG14V2QRMJPIEY90': 8,
#  'WJ0#8P8H020K1NX8RG7ML8T7A0': 1,
#  '3EYXD7BORTEZ14V2QRMJPIEY90': 6,
#  'K2FOVVWXSBEP0V6EZJ59KGHU91': 4,
#  '9$Z5NQ3H74XY1M5FUFP5I$2U91': 0,
#  '12GRWT8QS3EE1PX8RG7ML8T7A0': 0,
#  'T18ERIQL1G#R0D2#9XYXOUEU91': 0,
#  'S9ITFO6OM#YX18XJ$X2GZV1U91': 0,
#  'IRQR$RVEFTCH1WY8Y41C3W1U91': 0,
#  'GFSQDDW1H5MT1NX8RG7ML8T7A0': 6,
#  '91CNEI28PMLH14V2QRMJPIEY90': 0,
#  '8VQVU9C5OIAI1R5ZPVSMNS#T91': 8,
#  'JR4WQPB17ZW501HYC28LRT4U91': 0,
#  'Z5E4QETGR5A81TKF#6P2WYLU91': 0,
#  '670N9MT23$SR1DCT2J1DDVFU91': 0,
#  'Z2FS#LHOYIPG09BJW8U4#SNU91': 9,
#  '51PC7RAGO4#C01HYC28LRT4U91': 0,
#  '#SG3F6Q4EG$#0TKF#6P2WYLU91': 2,
#  'V#4TBHM2CN8V0V6EZJ59KGHU91': 4,
#  '8VCRI9L#LZ5H1S76ZFRG$SNU91': 0,
#  'P5O6A100Q66M16VDR7NOG$2U91': 0,
#  '85B$IYY3OL4B1NX8RG7ML8T7A0': 7,
#  'RADLDL62Y#KY1ZG214S$QZ2U91': 7,
#  '52D97#YH1IWG1DCT2J1DDVFU91': 0,
#  'U6YQW$CLX90E14V2QRMJPIEY90': 4,
#  '4TLOPMZDZNO91SS0YHV2URJU91': 0,
#  '1R#Z3VTDV1T$08XJ$X2GZV1U91': 7,
#  'LL24T0#BUMUS16VDR7NOG$2U91': 0,
#  '#YWL$B3JWA#V14V2QRMJPIEY90': 0,
#  '02$WD6YYBPSB0XC9F63XMQ#T91': 0,
#  'XH6NLNFUAPUU14V2QRMJPIEY90': 7,
#  'A2PPD7UCMW3Q1NX8RG7ML8T7A0': 7,
#  'DJT$6JD$0Z0K0NX8RG7ML8T7A0': 8,
#  '9HLH1SX4T9MW1M5FUFP5I$2U91': 4,
#  '3YHGBR$24ETF03EVNQP90#2U91': 4,
#  '0PPVW2WUCI2H0NX8RG7ML8T7A0': 9,
#  'AC3LYO2C7B$Q14V2QRMJPIEY90': 2,
#  '7G48T6DZE2V81EQT5KFUBW1U91': 4,
#  '4SA6B9J3XWZ51NX8RG7ML8T7A0': 6,
#  'D#462TJ6KEQQ14V2QRMJPIEY90': 8,
#  '23OZIWYOOVEZ09BJW8U4#SNU91': 0,
#  '$FNXQZNIFKMY1NX8RG7ML8T7A0': 1,
#  'Y9E$N79ECY5I04V2QRMJPIEY90': 8,
#  'JW63LYZ#G8D20NX8RG7ML8T7A0': 1,
#  'GBY2JY57KI591KP1$OHE1B6U91': 0,
#  'RV0E08FBCG5E1NX8RG7ML8T7A0': 0,
#  'PZ0UI9Z$L4Z71X9JIKKMFPKU91': 0,
#  'F04BIMS1L6FC14V2QRMJPIEY90': 2,
#  '82WT$T4PZ#9J08XJ$X2GZV1U91': 7,
#  'R0Y7$PI$ALC911HYC28LRT4U91': 2,
#  'QJEO9K7UXX9X1NX8RG7ML8T7A0': 1,
#  'JBXC5YUIS3L316VDR7NOG$2U91': 7,
#  'CPSJ4PHCYG$O0R5ZPVSMNS#T91': 6,
#  '6R43W64053OO0SS0YHV2URJU91': 8,
#  'TX$655H64$K21S76ZFRG$SNU91': 4,
#  '$L98TGITDRGO0TKF#6P2WYLU91': 0,
#  'VDJJB78HH8C#0X82LV9YJRJU91': 0,
#  '77YNTHHX78PQ06W1HTEMVMEU91': 8,
#  'DU7FYZW2$IIS0ZE3B2$E#KLU91': 8,
#  'HU09OSEO7W4N0NX8RG7ML8T7A0': 1,
#  'IZ#9MO9#40I31JJPFKEE0Z2U91': 0,
#  'YHDBS60896FF1D2#9XYXOUEU91': 9,
#  'T2W7GB1721VP19BJW8U4#SNU91': 0,
#  '0#IMRVUBO5AF14V2QRMJPIEY90': 0,
#  'I7BOMSTZHABD0X9JIKKMFPKU91': 8,
#  'HP2ZQENU80YV1CC$FDT11E6U91': 0,
#  'IS#L5X9AVELU0JJPFKEE0Z2U91': 0,
#  'PC105VDFMFX01KUS3JRJ8GFU91': 9,
#  'CH$V3Q3C9YSY1D2#9XYXOUEU91': 8,
#  '2821XO$LY4KS1JJPFKEE0Z2U91': 0,
#  '56J6CUVA92KA0YATAP92TUEU91': 8,
#  'A9S1Z6W7G2XQ0NX8RG7ML8T7A0': 9,
#  'PF6STL87QXEV0DCT2J1DDVFU91': 0,
#  'WCP7#DS4B#6G16V2QRMJPIEY90': 8,
#  'L8ERSTBDYPL90DCT2J1DDVFU91': 8,
#  '1CUVYKX4BKNB0PX8RG7ML8T7A0': 0,
#  'BSI9NRU2AIEX0T#K6JVYXMEU91': 0,
#  'S9R0YE44P5KN0WVOC4ZECT4U91': 3,
#  'BAUDWLCHADLH14V2QRMJPIEY90': 5,
#  'FQ#JFY5TZVV#08XJ$X2GZV1U91': 4,
#  '1$6G48DYSYSY04V2QRMJPIEY90': 2,
#  'UNGJYZSZJU7A0ZG214S$QZ2U91': 3,
#  'AWLK6MG4YYFV16V2QRMJPIEY90': 0,
#  'HVXVCD8YO37P1X9JIKKMFPKU91': 4,
#  'FE5B#VM8ZEIJ1S76ZFRG$SNU91': 0,
#  'PGB60KXJQFFT1NX8RG7ML8T7A0': 4,
#  'Y8Q#ZX5XV3G30K#S9M2BUGFU91': 0,
#  'K#98SBYRWIAP19BJW8U4#SNU91': 8,
#  '9DW36IAF83FS0IITDIAPBUFU91': 8,
#  'N6G10K50IG3Z1K#S9M2BUGFU91': 0,
#  'DA7IDWRDUMS#0M5FUFP5I$2U91': 0,
#  'JXE8ASKFZREL0WVOC4ZECT4U91': 7,
#  '0JOX6VBVQ6B60OKNZBG03LLU91': 5,
#  'IQ0767TEP4VN1BWKN##NAGHU91': 0,
#  '#RYS251YQHFC0K#S9M2BUGFU91': 0,
#  'G1#5NVV3QXWO14V2QRMJPIEY90': 1,
#  'T7OHDBSZM8JC1OKNZBG03LLU91': 4,
#  '#DE34JJ$UOWS1T#K6JVYXMEU91': 6,
#  'HR2N4KPKQGDC1XC9F63XMQ#T91': 0,
#  'BOMJ#GSF#73B04V2QRMJPIEY90': 9,
#  'GNRBKBXORL5M0NX8RG7ML8T7A0': 9,
#  '9#Z4LIEAB4GT09QRDFE7$58U91': 0,
#  'YY5X8Q477FHB0TKF#6P2WYLU91': 6,
#  'Q5GO8G3CWYCX1D2#9XYXOUEU91': 8,
#  'I$GVFTLRJ8IN06W1HTEMVMEU91': 3,
#  'NOEHTWML75$303AYHQV9168U91': 8,
#  'J87Z039AJAG619BJW8U4#SNU91': 1,
#  'LUWCEQZ99YTH0OKNZBG03LLU91': 4,
#  'FRDWLM54WF9U1M5FUFP5I$2U91': 4,
#  'T$G9L1FGHPH#0KUS3JRJ8GFU91': 0,
#  'VD4OT24SO#GV08XJ$X2GZV1U91': 0,
#  'PNS3HM41UBUN0YATAP92TUEU91': 8,
#  'S0SKNURZCJOQ08PTFAUF4QZT91': 7,
#  '$FS8$SL1CCGP1NX8RG7ML8T7A0': 9,
#  '#65#QL8EW9W80T#K6JVYXMEU91': 0,
#  '4S4HJHVY4#S30TI$B0IK2QZT91': 3,
#  'SSYHE28C8H300NX8RG7ML8T7A0': 7,
#  'B8EBLIQ9LLO#0NX8RG7ML8T7A0': 7,
#  '84R8$Y1IFKK31YXAVS6GYZ2U91': 6,
#  'K#2R0ZA0UUDI0UV54AM9CPKU91': 6,
#  'FL60QTJ5PE4G0CC$FDT11E6U91': 6,
#  'XJU7C828S#ZL0PX8RG7ML8T7A0': 8,
#  'OI4VNV2ASNMQ1TKF#6P2WYLU91': 0,
#  'GYSIV1N#2RBY0M5FUFP5I$2U91': 8,
#  'AN98$54FBJ9A114XGQACHC6U91': 0,
#  'CDPLZE2RHYP5014XGQACHC6U91': 7,
#  'AR7IB8RXK9UL11HYC28LRT4U91': 8,
#  '43LYO50U#LZW1WY8Y41C3W1U91': 0,
#  '4RSHBF6BHA4F13AYHQV9168U91': 9,
#  'P8RYUA#9$9WW0IITDIAPBUFU91': 0,
#  'LYC89YFW99YA0YATAP92TUEU91': 8,
#  'JP0WLNXXTJLQ1NX8RG7ML8T7A0': 6,
#  'EDSWIC6ZSTAT03EVNQP90#2U91': 7,
#  'YVXFY7Y1Y2BJ1T#K6JVYXMEU91': 0,
#  'R7HMOKHVUIK21KP1$OHE1B6U91': 7,
#  'PHRRI#$FNOHB14V2QRMJPIEY90': 0,
#  'A1A4B81KR6AU0EQT5KFUBW1U91': 3,
#  '0CMSO2893UPN0TKF#6P2WYLU91': 0,
#  'ERVQIIMHK6VK0IITDIAPBUFU91': 0,
#  'OC4JTYJOXY$I1IITDIAPBUFU91': 4,
#  '#2D9#KM8IP5K0TKF#6P2WYLU91': 5,
#  'AYJLGGAMEZOM0#DZEARJDT4U91': 0,
#  '2X2UW02I$FC7114XGQACHC6U91': 5,
#  '2$ATDILDUFN00D2#9XYXOUEU91': 0,
#  'T#YJJ7#68QDP1NX8RG7ML8T7A0': 1,
#  '#$A$E7UHS0DB1VFRIZC#$T4U91': 1,
#  '6YR#$J12AJR901HYC28LRT4U91': 0,
#  'WCO9F8Q9CDD$0NX8RG7ML8T7A0': 8,
#  'SA3HB04SA#801TKF#6P2WYLU91': 0,
#  '1LAJT0CX3UV71S76ZFRG$SNU91': 0,
#  'ENNWPJCGYMHI0XC9F63XMQ#T91': 4,
#  '6CCLM4T0T$UV0M5FUFP5I$2U91': 0,
#  'TEK$S1EE7ZJ216V2QRMJPIEY90': 1,
#  'WDYX0FO#TZDG0M5FUFP5I$2U91': 0,
#  'YGAQV8#U5SR20XC9F63XMQ#T91': 8,
#  'T7TAF01GV$RA14V2QRMJPIEY90': 8,
#  'ARZKXN1C7O#Q1KUS3JRJ8GFU91': 0,
#  'KE54Q2O#5LSI08XJ$X2GZV1U91': 0,
#  '5MO8E4TI5H#Y1NX8RG7ML8T7A0': 8,
#  'XH3Y6PZORL3X1NX8RG7ML8T7A0': 0,
#  'FGD990DH0AY50YATAP92TUEU91': 4,
#  'YLSQL3MF9$D31X9JIKKMFPKU91': 4,
#  'ML5BFN2#TP091WY8Y41C3W1U91': 5,
#  'EI6J2B89$THD0YATAP92TUEU91': 8,
#  'OYO#ATC6#I7W0R5ZPVSMNS#T91': 2,
#  'A0ZK9TTYTLL40R5ZPVSMNS#T91': 1,
#  'FDRLU1GFXQLT1#71OYZ1XQJU91': 0,
#  '#0VJ8LA$97ML1Q$3UK0GBQ#T91': 2,
#  '01D37FW3J7AX06W1HTEMVMEU91': 0,
#  'AM7IU1UUVH0714V2QRMJPIEY90': 7,
#  'GHM$UDFZFVQ21K0T5HBQA58U91': 4,
#  'SP0YB9F5AH0E0T#K6JVYXMEU91': 2,
#  'SP3GCYVK#3AM01HYC28LRT4U91': 6,
#  'E6R4AA1GAVKG1NX8RG7ML8T7A0': 7,
#  '9KPCVQK1X5J214V2QRMJPIEY90': 0,
#  'OWUWVMV1E7M114V2QRMJPIEY90': 8,
#  'FOW88HRW$74A1D2#9XYXOUEU91': 0,
#  '3A2B4140VAO00T#K6JVYXMEU91': 1,
#  'BZHS7#K$$XJL1X9JIKKMFPKU91': 0,
#  '56W9HZ6L46$Q1NX8RG7ML8T7A0': 3,
#  'NT$JJRF01G5B19BJW8U4#SNU91': 8,
#  '2UOHK885XU6R1NX8RG7ML8T7A0': 6,
#  '8P$P#UVBDTZK18XJ$X2GZV1U91': 2,
#  'T5NA6WRW0EXM1IITDIAPBUFU91': 8,
#  '9O0V#YSNHMDR1#71OYZ1XQJU91': 0,
#  'TC552Z3H1$AI16VDR7NOG$2U91': 8,
#  '7ZBX1PTMLNCZ0ZE3B2$E#KLU91': 0,
#  'AIYV5OZE0SGT014XGQACHC6U91': 6,
#  '50Q7LDAIZ3VP1D2#9XYXOUEU91': 0,
#  '6IO8YPRFZ1MG04V2QRMJPIEY90': 2,
#  'AAY20TSNIS4O0WY8Y41C3W1U91': 0,
#  'YU9CVZK$L8Z50NX8RG7ML8T7A0': 7,
#  '604MD4WC9NUT1PX8RG7ML8T7A0': 0,
#  'MNP9HL247HX90YATAP92TUEU91': 9,
#  'XB2AL18YJYP20S76ZFRG$SNU91': 0,
#  'HRUGQA$GQJA804V2QRMJPIEY90': 7,
#  'Y5ZN6P6ELOUW06V2QRMJPIEY90': 8,
#  '71L$CGVHNKHU014XGQACHC6U91': 7,
#  'YAU$99DMPI4#07MXD55I3QZT91': 0,
#  'B4N1XADD5Q8Q1PX8RG7ML8T7A0': 0,
#  'KAZEQS70VBT51JJPFKEE0Z2U91': 1,
#  'Z4ZZIJCZG6NS1YATAP92TUEU91': 0,
#  'T51AWRC79B691OKNZBG03LLU91': 0,
#  'XC4HSV4OD3F206V2QRMJPIEY90': 8,
#  'OG98C01KM6CU1#DZEARJDT4U91': 0,
#  '24D0VOP3UWK41Q$3UK0GBQ#T91': 0,
#  'F1KRR9NLSFDQ0KUS3JRJ8GFU91': 0,
#  'F$HIYJ0BE24E14V2QRMJPIEY90': 2,
#  'JO5IRXI1H#MN1NX8RG7ML8T7A0': 2,
#  'GWIUJCH5T7680UV54AM9CPKU91': 4,
#  '50RRKJO9LZ#T04V2QRMJPIEY90': 0,
#  'HSE0PO3FDFV31NX8RG7ML8T7A0': 8,
#  'QK60QXTUZ$8E0KUE49ZQ4UZT91': 0,
#  'WJX109C27AEI07MXD55I3QZT91': 3,
#  'FFW5VGCZLU#20NX8RG7ML8T7A0': 7,
#  '9$H6CST4T5FY15F3A3DJI2$T91': 0,
#  'BFQT5KCECXUF1DCT2J1DDVFU91': 8,
#  '4AZ4LR8QO3ZG1LIIH4STYR$T91': 7,
#  'GAVN$OU4M7SE0#71OYZ1XQJU91': 6,
#  '#$6C1HBMVY1M0NX8RG7ML8T7A0': 9,
#  '4P3A4BFTXOIZ04V2QRMJPIEY90': 3,
#  '2B2J4S5TACBF0KUS3JRJ8GFU91': 7,
#  'GB40SLCCXHF804V2QRMJPIEY90': 2,
#  '2Z$G2ZL4S3GL0NX8RG7ML8T7A0': 2,
#  'KD27D9XOHI1Y14V2QRMJPIEY90': 8,
#  'RUQ8M3#46$E41NX8RG7ML8T7A0': 6,
#  'ZP0C$E52WRJM17MXD55I3QZT91': 0,
#  'SIU$56S6S7Q40NX8RG7ML8T7A0': 2,
#  'RQG4OFVCII5506W1HTEMVMEU91': 9,
#  '$8HJT3ZHVTH306V2QRMJPIEY90': 4,
#  'J3EWTVZ#E72I04V2QRMJPIEY90': 2,
#  'DO9XJ8WKNU5$04V2QRMJPIEY90': 6,
#  '3T7T8AMMBNUL1NX8RG7ML8T7A0': 2,
#  '66PS6S26VEEI1NX8RG7ML8T7A0': 2,
#  'ZAOQR2ZHFD2W09BJW8U4#SNU91': 9,
#  'EPHHUP#EJQPO11HYC28LRT4U91': 0,
#  'P4K$GZ97S54M0KUE49ZQ4UZT91': 0,
#  'UG17A66O7YN919BJW8U4#SNU91': 3,
#  'LT76S4PZE61Z1YATAP92TUEU91': 0,
#  'PC225LXM456606VDR7NOG$2U91': 2,
#  'XQB1L6DB#SPO09I5WB#S6VZT91': 0,
#  'MRAQYX#K09SZ04V2QRMJPIEY90': 6,
#  'PUY3VNZ0HU0D04V2QRMJPIEY90': 7,
#  'AV6B9SN0GPDN04V2QRMJPIEY90': 8,
#  '#MJ4TVB77CS6003E$W8022#T91': 0,
#  'UN#2472Y3I8J1KUS3JRJ8GFU91': 7,
#  'I2308Z5HD52W04V2QRMJPIEY90': 2,
#  'C2#TWN7SMP8Y04V2QRMJPIEY90': 2,
#  'I44JHOIA8WNG0#DZEARJDT4U91': 0,
#  'PYQAW9241EMY0X9JIKKMFPKU91': 9,
#  '$KNWUND8OG0B1D2#9XYXOUEU91': 9,
#  'UUEX#7K63B6Q114XGQACHC6U91': 7,
#  'GQTI25IQZILI17MXD55I3QZT91': 9,
#  'VBREW#HQWKY910N9LDL2T$ZT91': 0,
#  'ZTHPZL080VL90C8O0O6131#T91': 0,
#  'E2V5Z77OWE160KP1$OHE1B6U91': 2,
#  'C#6U#PQ8L9I00CC$FDT11E6U91': 0,
#  'C1UZ5E8QAJAS1JSEW0DWRZZT91': 0,
#  'Z4AY$22PFSRF0XC9F63XMQ#T91': 0,
#  '3K9PAM94T$620ZG214S$QZ2U91': 4,
#  '3H$FX5NRH8UH1DCT2J1DDVFU91': 0,
#  'DR6USW1RM1W11NX8RG7ML8T7A0': 2,
#  'EUVE340EOLLB0UV54AM9CPKU91': 1,
#  'OB349XQ#YL#P1NX8RG7ML8T7A0': 5,
#  'IAIH4HFK7JA816VDR7NOG$2U91': 0,
#  '9$$8WSQ1QRK304V2QRMJPIEY90': 2,
#  '#6V#XZWPKINF04V2QRMJPIEY90': 2,
#  '27NAL7CEU$JB0CC$FDT11E6U91': 7,
#  '14J$S2Q9DYGA06VDR7NOG$2U91': 9,
#  'L9ABWL#12MQB19I5WB#S6VZT91': 3,
#  '0T7XZZQQTGK90DTAESCA06#T91': 8,
#  'C#YIW#3UDJ#I14V2QRMJPIEY90': 0,
#  '46SNMO8IKE4F0YXAVS6GYZ2U91': 0,
#  'NQNARUAR7IEM04V2QRMJPIEY90': 0,
#  'M02CGHICJFZV1NX8RG7ML8T7A0': 1,
#  'XA2IARLWBB0P0#DZEARJDT4U91': 8,
#  'TK36SK0JB5NL0NX8RG7ML8T7A0': 6,
#  'VZURLE$QMYI#0S13CP8$MRJU91': 4,
#  'Y6EI440HWM3U04V2QRMJPIEY90': 2,
#  '16LM#ZDY2XPU0NX8RG7ML8T7A0': 2,
#  '0$BFZG5NE$VH11HYC28LRT4U91': 8,
#  'PRAKQL8EDZ1Z0NX8RG7ML8T7A0': 2,
#  'WOUJHBXRQH$R1NX8RG7ML8T7A0': 9,
#  'JPCXY12JVWB11YXAVS6GYZ2U91': 0,
#  '#VVM9QAWCOW71NX8RG7ML8T7A0': 0,
#  'VMGMM41VA#901NX8RG7ML8T7A0': 2,
#  'HJ9QBMNS$AK106W1HTEMVMEU91': 4,
#  'HIMIARUDFB2P1NX8RG7ML8T7A0': 6,
#  'PZDKP46M3W5M1R4RGIATDWZT91': 0,
#  'W61L4ZW3GP2606V2QRMJPIEY90': 7,
#  'MTPTW67R4HJ91C8O0O6131#T91': 4,
#  'NSNL2#QTVODV09I5WB#S6VZT91': 7,
#  'FSJQ$SAD63VR0V6EZJ59KGHU91': 8,
#  'UEN05HCRE$D50TKF#6P2WYLU91': 9,
#  'R#M#KB6GDMWN09I5WB#S6VZT91': 0,
#  '0TC8GN17B9II0DCT2J1DDVFU91': 6,
#  'O7$3K$J0URC607MXD55I3QZT91': 8,
#  'B3557G483L1T0NX8RG7ML8T7A0': 1,
#  '3L3KEZM4Z#ZG06V2QRMJPIEY90': 0,
#  '0CSR#ER3A3T509BJW8U4#SNU91': 7,
#  'IT0LP5RUW$4Z0NX8RG7ML8T7A0': 0,
#  'JM4DNA25HL3V0DCT2J1DDVFU91': 6,
#  'XA8#UQCQEP1L0UV54AM9CPKU91': 6,
#  '6AS8QGZ8L37M003E$W8022#T91': 3,
#  '3OPLBFGLR2XA0D2#9XYXOUEU91': 0,
#  '98Y64ZD9AT#O0Q$3UK0GBQ#T91': 8,
#  '24T3QCMWCYF014V2QRMJPIEY90': 2,
#  '1WNQ8C#3B49L0S76ZFRG$SNU91': 5,
#  'HAQ0UY2YZ5TF09BJW8U4#SNU91': 8,
#  'JR4#SH8VVZL904V2QRMJPIEY90': 8,
#  'W5020#K43WR41KUS3JRJ8GFU91': 0,
#  '9EMWBA2K77H41NX8RG7ML8T7A0': 4,
#  '74DV07UZFQJK1X82LV9YJRJU91': 1,
#  '#$MJ2GLY75VW0NX8RG7ML8T7A0': 2,
#  'U0YWP3S2JFWR103E$W8022#T91': 7,
#  '#32E1YXAXG7I1LO4PYJ5UK#T91': 8,
#  'FTKNILHZS4FI09I5WB#S6VZT91': 7,
#  '7SKG7Y1BZQ1S1JSEW0DWRZZT91': 2,
#  'C#E2IXXNND6A1S76ZFRG$SNU91': 4,
#  'OO8TX99$Y5JE0YATAP92TUEU91': 0,
#  'T#CD7PFRI4IT0ZG214S$QZ2U91': 4,
#  'CXG4UDFVRF8N0KUS3JRJ8GFU91': 0,
#  'F4SW7WJE4XO61X9JIKKMFPKU91': 0,
#  '3JI267WYTKQH0XC9F63XMQ#T91': 0,
#  'SYNDM7RUO87I0T#K6JVYXMEU91': 0,
#  'SCJ#3E4IP$VP0M5FUFP5I$2U91': 4,
#  '7CA6U0KUHI2D00N9LDL2T$ZT91': 1,
#  '46D5V4XZCBVW1NX8RG7ML8T7A0': 7,
#  'OAQOU549O3360T#K6JVYXMEU91': 0,
#  'TZO22SUF76R30NX8RG7ML8T7A0': 9,
#  'C$#CIW4Z5TJQ04V2QRMJPIEY90': 7,
#  'BNOKV4JS8FP01#DZEARJDT4U91': 8,
#  'PH8QNF9XDK1K09I5WB#S6VZT91': 0,
#  '0#PRFSP#IXF504V2QRMJPIEY90': 8,
#  '0NS$4#DC5FAU1D2#9XYXOUEU91': 8,
#  '9MDWWV##MH5701HYC28LRT4U91': 4,
#  'GAP774YL$94F0B4WOEBF4I$T91': 0,
#  'S3J$V46V#T$V1IITDIAPBUFU91': 0,
#  '0HBJU623A2XM1R4RGIATDWZT91': 2,
#  'DOQ9485RWDIB06W1HTEMVMEU91': 5,
#  'R6SF1FTYEHKY0BWKN##NAGHU91': 0,
#  'DXH9GHZEHLXF0WY8Y41C3W1U91': 8,
#  'WYR8T1#$36UB0TKF#6P2WYLU91': 8,
#  'UDEDHZA79G#U1D2#9XYXOUEU91': 0,
#  'H#MZDM6UG4YM14V2QRMJPIEY90': 2,
#  'PBV0$#YESMBF04V2QRMJPIEY90': 1,
#  'UMKHOB66ITCL1DCT2J1DDVFU91': 2,
#  'YW#8E6BR20JJ14V2QRMJPIEY90': 2,
#  'ZXMR9M6L0G3404V2QRMJPIEY90': 2,
#  'DZW9N39E8LOQ04V2QRMJPIEY90': 2,
#  'XYU4UK1F9E9Z1M5FUFP5I$2U91': 0,
#  '9E2L0PZOWK4D14V2QRMJPIEY90': 0,
#  '1R52YS4627YY0NX8RG7ML8T7A0': 6,
#  'Q5X54WUB9LG714V2QRMJPIEY90': 6,
#  'MXOBJWE4MLGR04V2QRMJPIEY90': 0,
#  'JKRNFLP8VFHL14V2QRMJPIEY90': 0,
#  'ZET47HWX1IZY1NX8RG7ML8T7A0': 4,
#  'CP90$N$UGJYV04V2QRMJPIEY90': 4,
#  'XFWV$J5W9X3S1DCT2J1DDVFU91': 9,
#  'GLQJ3EB5POFI0PX8RG7ML8T7A0': 7,
#  'FCN$TGTI$FVP09I5WB#S6VZT91': 4,
#  'Y5IW1XZJKXYK0NX8RG7ML8T7A0': 0,
#  '5ORMMH9RPUEV0NX8RG7ML8T7A0': 0,
#  'IOK9462C0XOX04V2QRMJPIEY90': 0,
#  'S4DD8C6JIMNV1ZG214S$QZ2U91': 0,
#  'MHNKS$TN$O2$09BJW8U4#SNU91': 8,
#  '$27NUG#LN11106W1HTEMVMEU91': 4,
#  '20O9Y4OELCSV1S13CP8$MRJU91': 0,
#  'B5CHTQQXR1MS1PX8RG7ML8T7A0': 0,
#  '814BM3TLYYOH0PX8RG7ML8T7A0': 0,
#  '6AI3HE0ETWWH0M5FUFP5I$2U91': 8,
#  'PAFQ1SMI38QP04V2QRMJPIEY90': 0,
#  'GTJL5BVFDG3L11HYC28LRT4U91': 0,
#  'WFTIUGHXJ3Z81NX8RG7ML8T7A0': 4,
#  'I4399LGMAJVV0NX8RG7ML8T7A0': 7,
#  'I#RWPO$Q83LF1K#S9M2BUGFU91': 8,
#  'F7RFB8SD9FZQ0NX8RG7ML8T7A0': 1,
#  'IJO3H#I68HWC04V2QRMJPIEY90': 2,
#  'OCE#FZ$3DNHG1NX8RG7ML8T7A0': 9,
#  '37PQAZSWY6RV0NX8RG7ML8T7A0': 0,
#  'E5Q5V#6B68IT14V2QRMJPIEY90': 2,
#  'CQ8X9$04UB9805F3A3DJI2$T91': 4,
#  'XYZZTHCN4WTT1C8O0O6131#T91': 0,
#  'G0TDV3D6E6VI1TKF#6P2WYLU91': 0,
#  'WLPJQNL4XNSN0X82LV9YJRJU91': 8,
#  'ZV$8Q7FO3JCB04V2QRMJPIEY90': 4,
#  'I70NDSRY2MI514V2QRMJPIEY90': 2,
#  '5U9ACDQCAZ0J06W1HTEMVMEU91': 8,
#  'QUB49NRBX26O11HYC28LRT4U91': 0,
#  'WPAZKOGROHHB0X9JIKKMFPKU91': 7,
#  '3709QEWFUVK214V2QRMJPIEY90': 2,
#  'FLB20DY6REHW04V2QRMJPIEY90': 2,
#  'E1014PXOGB$H1PX8RG7ML8T7A0': 9,
#  '$TDYZQY14B8M0D2#9XYXOUEU91': 8,
#  'JTZD97RO5ABC14V2QRMJPIEY90': 0,
#  'GQT73B#7Y87A14V2QRMJPIEY90': 3,
#  'BLY$BFX#0I751NX8RG7ML8T7A0': 2,
#  'Y2R9FEIMDUFV14V2QRMJPIEY90': 0,
#  '6SSPMJPOJA3Z04V2QRMJPIEY90': 0,
#  '6K#TK#4YZ84N09BJW8U4#SNU91': 0,
#  '5$QLV4BZWHQ91NX8RG7ML8T7A0': 0,
#  'I6EAE99GVRTO0#DZEARJDT4U91': 0,
#  'TCTW0QOLLUOK19BJW8U4#SNU91': 0,
#  '129CAW#Z2$#00NX8RG7ML8T7A0': 0,
#  'CP7I2S$RZAUO0PRENUGLEJ$T91': 0,
#  '1C6QHEV4N$4S14V2QRMJPIEY90': 2,
#  'IE2LGD2NVYEG14V2QRMJPIEY90': 2,
#  '3RKH089SAMNZ0T#K6JVYXMEU91': 2,
#  'G9$036G3NV5G0R5ZPVSMNS#T91': 0,
#  'GG$T9VN$5BKQ04V2QRMJPIEY90': 6,
#  '#ZBMHL$OOA3214V2QRMJPIEY90': 0,
#  '1XNS#SUC23KP04V2QRMJPIEY90': 8,
#  'SQLYHS$F6C2Z1NX8RG7ML8T7A0': 2,
#  'MVFK9UXY778X0NX8RG7ML8T7A0': 0,
#  '2OJOC8$AMK7A0ZE3B2$E#KLU91': 4,
#  '8DCD#$7667$F1T#K6JVYXMEU91': 0,
#  'HF0Q3HJLF0341Q$3UK0GBQ#T91': 8,
#  'QSFNHNQQ0T7B1WVOC4ZECT4U91': 2,
#  'M9DJ4$0RCCAQ04V2QRMJPIEY90': 1,
#  'Y0F2$DMI#NM81WY8Y41C3W1U91': 6,
#  'OYJ5X90ZB8HQ1D2#9XYXOUEU91': 0,
#  'IPVST9P83L4#0NX8RG7ML8T7A0': 7,
#  'PEOTD80S4KNL04V2QRMJPIEY90': 7,
#  'WCF8#H4H#COD1T#K6JVYXMEU91': 0,
#  'EIL7XFLFTTZF1XC9F63XMQ#T91': 0,
#  'M70#JD#PP0JY0OKNZBG03LLU91': 5,
#  'NN8ISCO#53$S14V2QRMJPIEY90': 0,
#  'PSIJFY06ICVT114XGQACHC6U91': 3,
#  'QNSC9ZGKGKS81YATAP92TUEU91': 7,
#  'BJ2$QJZD2D5G09BJW8U4#SNU91': 2,
#  'BUNBR6YPS#VY0ZG214S$QZ2U91': 4,
#  'CIBVLUEEMSMP1NX8RG7ML8T7A0': 2,
#  'XX9NY7O$MZFB1NX8RG7ML8T7A0': 0,
#  'SLBKUPMMCOTY1T#K6JVYXMEU91': 4,
#  '6N4W3AYZ7ML311HYC28LRT4U91': 8,
#  'B3HD72L1Y$4G1GI4#KMZPZZT91': 8,
#  'TAT8NJSJV1SF1S76ZFRG$SNU91': 8,
#  'SZLUP#AXB0TI0NX8RG7ML8T7A0': 3,
#  '90OCRCUUYDOW03AYHQV9168U91': 0,
#  'RO##1UFNV6601NX8RG7ML8T7A0': 2,
#  '37V9TR$FHXLS1NX8RG7ML8T7A0': 9,
#  '39NM1WWDV$Y#0S76ZFRG$SNU91': 0,
#  'T3791ROZ3Q4L1NX8RG7ML8T7A0': 8,
#  '5XH7C#XWAVE904V2QRMJPIEY90': 8,
#  'PY4VO1LZBTDV1NX8RG7ML8T7A0': 6,
#  'C7B8KNQSPFM#0NX8RG7ML8T7A0': 0,
#  '9##1VSQUBOH#04V2QRMJPIEY90': 8,
#  'BC14#Y1RXO6S0NX8RG7ML8T7A0': 2,
#  'OT5IZPCZYM2814V2QRMJPIEY90': 7,
#  'YU#3A6OH51DQ04V2QRMJPIEY90': 8,
#  'PM57W$$PID071NX8RG7ML8T7A0': 9,
#  'GMEZPMC4LFWQ1ZE3B2$E#KLU91': 2,
#  '6F5QWSUR#8PC04V2QRMJPIEY90': 2,
#  '7RYDS8WR#V4V17MXD55I3QZT91': 0,
#  'IT7C3HAR6ZI60NX8RG7ML8T7A0': 4,
#  'BG6Q3IB0U4YM01HYC28LRT4U91': 0,
#  'UBXF38EABQ040NX8RG7ML8T7A0': 0,
#  'XOZUBHCB$JS614V2QRMJPIEY90': 4,
#  'A74RT18V5IV01OKNZBG03LLU91': 2,
#  'OYDOJZ6CDEDV0NX8RG7ML8T7A0': 6,
#  'CUWR4KE9EGFN1M5FUFP5I$2U91': 2,
#  'GY#$ID0AU#AR0ILFLDO8D1$T91': 4,
#  'Z#VBAYMANHOF0NX8RG7ML8T7A0': 0,
#  'ED1599K00RNO1NX8RG7ML8T7A0': 5,
#  '8YY4JZLA112N1NX8RG7ML8T7A0': 7,
#  'O$QHO77P04D21T#K6JVYXMEU91': 9,
#  '6QN4LYU1N8TB0R5ZPVSMNS#T91': 2,
#  'LIIOTJSH1AT#0NX8RG7ML8T7A0': 0,
#  'ZZQV$1PPHVYG14V2QRMJPIEY90': 0,
#  'D2VQHAKFHM1G0EQT5KFUBW1U91': 7,
#  'ZBRF6EF1DS3T014XGQACHC6U91': 7,
#  'GAAR1SS0L7H811HYC28LRT4U91': 0,
#  'JW3TT1BOZECS04V2QRMJPIEY90': 7,
#  '4H12EKP4CS#906VDR7NOG$2U91': 7,
#  'D3IY4RI5TNNY0UV54AM9CPKU91': 0,
#  '$7NAY6QB4TNC1#DZEARJDT4U91': 8,
#  'V9ZE4O$RC7DC0NX8RG7ML8T7A0': 9,
#  'H3GXZQEVHWU704V2QRMJPIEY90': 7,
#  '#RGA5H1XONUU04V2QRMJPIEY90': 8,
#  'DIP$O32LI7KV04V2QRMJPIEY90': 1,
#  '4ZRN57YAHTNO1V6EZJ59KGHU91': 0,
#  'DVW4MA993XN714V2QRMJPIEY90': 0,
#  'V$W$689RE6OL1YXAVS6GYZ2U91': 3,
#  'WRO1ULL58EW50BWKN##NAGHU91': 0,
#  'STQ1G1SQTZKP0NX8RG7ML8T7A0': 2,
#  'KWMOA496NMT10S76ZFRG$SNU91': 0,
#  'U5S6ZDOHV7GZ1NX8RG7ML8T7A0': 2,
#  'AXNYA42LGRSL14V2QRMJPIEY90': 0,
#  '72XX7AZDPDI90#71OYZ1XQJU91': 1,
#  'OUS56YLXBQX31YXAVS6GYZ2U91': 6,
#  'VCKT5EZFB2PP04V2QRMJPIEY90': 2,
#  'YD8RNHKG8W$E1K0T5HBQA58U91': 5,
#  'NYD#GGIHH6L20CC$FDT11E6U91': 4,
#  'JW6CE3LDI8GI0NX8RG7ML8T7A0': 0,
#  'ZUVUUP5GAQ4606W1HTEMVMEU91': 0,
#  'DRXK0OX0$#TO0S76ZFRG$SNU91': 9,
#  'U7N05JPB0VQG0YATAP92TUEU91': 8,
#  'ZW2NT#A2PF0T0ZG214S$QZ2U91': 1,
#  'I$RO44P4Z3DK06VDR7NOG$2U91': 0,
#  'RHOMT7H9XAVL16VDR7NOG$2U91': 0,
#  '6VK7PC0E4UKP1XC9F63XMQ#T91': 6,
#  'C40FI$BUDEP30NX8RG7ML8T7A0': 9,
#  '1DE4IDGBA7240D2#9XYXOUEU91': 2,
#  'WU8716HUBV5X1XC9F63XMQ#T91': 0,
#  'OXK9RF879TIG14V2QRMJPIEY90': 0,
#  '4CPGN5R2O9ZY14V2QRMJPIEY90': 8,
#  'CJOU$#LA9IIO0S76ZFRG$SNU91': 0,
#  'B250W8IT01SN1XC9F63XMQ#T91': 0,
#  'A2HOD8I3JAU804V2QRMJPIEY90': 2,
#  '5M71IDRV71QC0SS0YHV2URJU91': 6,
#  '84#8V33PTVLV1NX8RG7ML8T7A0': 0,
#  'NB57UBKIUB1019BJW8U4#SNU91': 8,
#  'NVDGAY71SI#R04V2QRMJPIEY90': 4,
#  'T749G36QB07$0UV54AM9CPKU91': 4,
#  'ZT4ZFMD44WTB06V2QRMJPIEY90': 8,
#  'Q#OBA9$SXD2$0Q$3UK0GBQ#T91': 6,
#  'S2Q9U6HUHEXV0NX8RG7ML8T7A0': 2,
#  '8CRZV5FHJNMR04V2QRMJPIEY90': 1,
#  'HSO5561B7UQ81NX8RG7ML8T7A0': 2,
#  'X53BVGN31ZYA04V2QRMJPIEY90': 6,
#  'LLQLX#ZON83G1R5ZPVSMNS#T91': 8,
#  'MBCJE7Z0I68J06V2QRMJPIEY90': 0,
#  '$DX9NPYAT90H14V2QRMJPIEY90': 0,
#  'G#CJM45EMQSG1#DZEARJDT4U91': 8,
#  'X1FRUXN5TFNQ16VDR7NOG$2U91': 2,
#  'H72IO99LSLXU1Q$3UK0GBQ#T91': 8,
#  '4SS8SNVD6TUC04V2QRMJPIEY90': 6,
#  'FRMH7GCA6HYA1NX8RG7ML8T7A0': 2,
#  '6F5BR6BCG#TH1KUS3JRJ8GFU91': 0,
#  'HGBXDW32FYNZ1OKNZBG03LLU91': 8,
#  'YNIR$2#TF0Y01M5FUFP5I$2U91': 0,
#  '62OG0NR$CA6Z0TI$B0IK2QZT91': 0,
#  'VC6XS12ULB6Q1YATAP92TUEU91': 0,
#  '9IRM#GDFA8I314V2QRMJPIEY90': 0,
#  'XZ8TFTM34UMX1IITDIAPBUFU91': 0,
#  '6JS3F1R2JP7#04V2QRMJPIEY90': 0,
#  '$V$LWB80PYD40WY8Y41C3W1U91': 0,
#  '22NBHZ036SCS04V2QRMJPIEY90': 2,
#  '67SZKS$5RCIM0CC$FDT11E6U91': 0,
#  'UFYV$ASU#P5S1K0T5HBQA58U91': 0,
#  'C25ZDMHGI8D50V6EZJ59KGHU91': 0,
#  'K7EKKMA8BVCR1K#S9M2BUGFU91': 4,
#  '1#NQHNCQVJE60S13CP8$MRJU91': 6,
#  'TBT5N6TZM0YU01VF8IQ3TT4U91': 4,
#  '6DDKAJRZ$NF51UV54AM9CPKU91': 8,
#  'UF56$H7OUGW31ZE3B2$E#KLU91': 8,
#  '4VO#BUMNOIKM1#DZEARJDT4U91': 4,
#  'PXE5EKXTJY6V01HYC28LRT4U91': 8,
#  'P9DLIXV3XW2A0NX8RG7ML8T7A0': 6,
#  '4KZ5TJ56#UFD03AYHQV9168U91': 0,
#  'NWRKK28BGYYK1NX8RG7ML8T7A0': 4,
#  'ETAGDO7#DZNK1NX8RG7ML8T7A0': 4,
#  'CTJUAPMKBCZK04V2QRMJPIEY90': 2,
#  '03AA37MM5HR60NX8RG7ML8T7A0': 5,
#  '202PKEM4SJ2219BJW8U4#SNU91': 0,
#  'A3$ZLZ9QUYDV1KUS3JRJ8GFU91': 0,
#  'NTORLE9UP15I0DCT2J1DDVFU91': 9,
#  '#T46J#WUN9W21KP1$OHE1B6U91': 0,
#  '$5DRTG5YYUID1K#S9M2BUGFU91': 2,
#  'AD4OLO6UOYNO03AYHQV9168U91': 4,
#  'FAQPKJLQK1R01NX8RG7ML8T7A0': 0,
#  'E0HQHTD$XZWV1ZG214S$QZ2U91': 0,
#  'IPKQQCNWWMOM0DCT2J1DDVFU91': 8,
#  'X6S$Q#R2IVE804V2QRMJPIEY90': 0,
#  '7LEQPEZUYXVK11VF8IQ3TT4U91': 6,
#  'W9S6BIPVRS#Y04V2QRMJPIEY90': 9,
#  '9FR2XV569XUR0X9JIKKMFPKU91': 0,
#  'MVYFHP#N4HM90CC$FDT11E6U91': 2,
#  '#FO06SLY5LF51T#K6JVYXMEU91': 9,
#  'DVX2DTO6VIWX1D2#9XYXOUEU91': 0,
#  'YEG6NKY3CC$N0K#S9M2BUGFU91': 5,
#  '1XKWN3#HR86514V2QRMJPIEY90': 3,
#  'ZMNFK84WFVQG0UV54AM9CPKU91': 0,
#  'D2$87OEU6P6H04V2QRMJPIEY90': 9,
#  'DDJPYX1CAMJG04V2QRMJPIEY90': 6,
#  '3G49WHUK0YU#0KUS3JRJ8GFU91': 8,
#  '9K4TKNOD0#ZP1D2#9XYXOUEU91': 2,
#  'AY$RE2PIYV#V1#71OYZ1XQJU91': 9,
#  'EG4SSC0YYWAN0R5ZPVSMNS#T91': 0,
#  'D8E2KRMYH3GV1NX8RG7ML8T7A0': 2,
#  'I$FNTKEEUCWY0NX8RG7ML8T7A0': 8,
#  '7#F#J$IPFVNH1OKNZBG03LLU91': 8,
#  '3M1FS$Q7OU8V1NX8RG7ML8T7A0': 7,
#  'R820QPRHSYQT0OKNZBG03LLU91': 8,
#  'D0SO#729T07H1NX8RG7ML8T7A0': 2,
#  '$SDGBDT7AB1A04V2QRMJPIEY90': 2,
#  'P5DR5XP$N9GI1NX8RG7ML8T7A0': 7,
#  '260H68A9Z1JD1NX8RG7ML8T7A0': 2,
#  '3Y2$ODQX3JUJ1NX8RG7ML8T7A0': 3,
#  '9S6X3WHZ64#X0NX8RG7ML8T7A0': 2,
#  'G73O74BSNYZ214V2QRMJPIEY90': 4,
#  '4GX3P6KLJCK81NX8RG7ML8T7A0': 1,
#  'F7Z9$CIEXCB40NX8RG7ML8T7A0': 2,
#  'UNLUCWBXFC#H0NX8RG7ML8T7A0': 0,
#  'XZKZK2EEBBYC1PX8RG7ML8T7A0': 3,
#  'JN4ORHPQ$Q$L0NX8RG7ML8T7A0': 4,
#  'DC01NOVI5UX914V2QRMJPIEY90': 4,
#  '0LM7B943O85U1NX8RG7ML8T7A0': 2,
#  '0VH3147INBBQ1K#S9M2BUGFU91': 0,
#  'T9HF#27GL3C51SS0YHV2URJU91': 3,
#  'J#X0Q3RY9Q1E08XJ$X2GZV1U91': 3,
#  'T77GI9BPM4UL01HYC28LRT4U91': 4,
#  'XFFK814$I6U70M5FUFP5I$2U91': 0,
#  'L$MTPBRFVYKF19QRDFE7$58U91': 7,
#  '614YQ#64G08O0X9JIKKMFPKU91': 4,
#  'Y#FC9VNVE5TP1K0T5HBQA58U91': 2,
#  '8D9GVQAD5QJX0M5FUFP5I$2U91': 8,
#  '4I3YH#O0Y7NJ1WVOC4ZECT4U91': 8,
#  'C$JQ97Z4FGDS0X82LV9YJRJU91': 0,
#  '$C$YS6VA790K1T#K6JVYXMEU91': 8,
#  'STP8W2#QDKP41K#S9M2BUGFU91': 9,
#  'SD#2N7NN05N80V6EZJ59KGHU91': 0,
#  '#9ZO4ITD7VQ20BWKN##NAGHU91': 8,
#  'RZ#QSBP$3QD204V2QRMJPIEY90': 9,
#  'RT2II77U9T0K1#DZEARJDT4U91': 4,
#  'BPO1VYIFZIKK0EQT5KFUBW1U91': 4,
#  'EFP$FJNPEPHG1OKNZBG03LLU91': 0,
#  'CMLOXZ6111DW1NX8RG7ML8T7A0': 2,
#  'SEW8I32WBCL21S76ZFRG$SNU91': 0,
#  'K7BP879K#$#X1X9JIKKMFPKU91': 8,
#  'NJJ$D92RHW2T0KUS3JRJ8GFU91': 0,
#  '52R7VSW05LHQ01HYC28LRT4U91': 0,
#  '#QDEQCYE1WHV04V2QRMJPIEY90': 9,
#  '1ISZVTVI0FUY1SS0YHV2URJU91': 1,
#  'G61PW97X7F8J1S13CP8$MRJU91': 7,
#  'VN1GT#CAC8#61T#K6JVYXMEU91': 5,
#  'R6XDSS53WBXM0NX8RG7ML8T7A0': 9,
#  'FI9S5B8SWPAP1TKF#6P2WYLU91': 0,
#  'KG8TPU97$WHM04V2QRMJPIEY90': 2,
#  'E81$FEYSZIWX1IITDIAPBUFU91': 0,
#  '2$45IALGQB9Y06VDR7NOG$2U91': 4,
#  '73RU725GQSKP0#DZEARJDT4U91': 8,
#  'MXX6V#$LHN5D0X9JIKKMFPKU91': 5,
#  '4CRVD4NJO7U40T#K6JVYXMEU91': 5,
#  'B3ZK3734$4RD03AYHQV9168U91': 0,
#  'O38MPDW9JP6R0ZG214S$QZ2U91': 0,
#  'RNMW9$$WF47A1BWKN##NAGHU91': 8,
#  'CIPUT$LBGGG41T#K6JVYXMEU91': 4,
#  '1GW4BHY4KTYQ0#71OYZ1XQJU91': 2,
#  '145VQO4VSC3A0KP1$OHE1B6U91': 4,
#  'L$ZIZZN2$WLA06V2QRMJPIEY90': 0,
#  '3QM0$62Q7ZEH1NX8RG7ML8T7A0': 7,
#  'JQHXG1$ML8P$06W1HTEMVMEU91': 0,
#  'G9BABH9MD8JV1NX8RG7ML8T7A0': 8,
#  'NNSWXC6X4LZA0NX8RG7ML8T7A0': 7,
#  '3OXH3731Y#1Z1KUS3JRJ8GFU91': 0,
#  'L90Y5NZMYRMW14V2QRMJPIEY90': 3,
#  'RPRP3LRB5GWG0NX8RG7ML8T7A0': 2,
#  'S2ZJRZSP$NUQ0DCT2J1DDVFU91': 0,
#  'ZW4WBINZS5U904V2QRMJPIEY90': 6,
#  '1FQC179LL#4#0NX8RG7ML8T7A0': 7,
#  'GCKGCF6#D20I04V2QRMJPIEY90': 3,
#  'J2GXKH2I#TT714V2QRMJPIEY90': 2,
#  'DOUOMVQBK$AQ1NX8RG7ML8T7A0': 2,
#  '5V63VTXLY5AD0ZE3B2$E#KLU91': 9,
#  'Y18OCWYO56800M5FUFP5I$2U91': 8,
#  '0GSC1G9JSVL514V2QRMJPIEY90': 2,
#  'R$RGM19JND4Q1NX8RG7ML8T7A0': 8,
#  'FROTE8D$GGY90NX8RG7ML8T7A0': 1,
#  'DFHZA7QHS17H1NX8RG7ML8T7A0': 1,
#  'VWY3820YLNFE0YXAVS6GYZ2U91': 5,
#  '9RAX28EHJAEI1NX8RG7ML8T7A0': 3,
#  'YRI4J$P813K514V2QRMJPIEY90': 3,
#  'GRFUES74H3DV1NX8RG7ML8T7A0': 2,
#  '5PM#PA1Q7PTY04V2QRMJPIEY90': 0,
#  'APFTZDTHJUA104V2QRMJPIEY90': 9,
#  'MCTB#1ECNEM$04V2QRMJPIEY90': 2,
#  'X5M3VR8#LO7O06W1HTEMVMEU91': 3,
#  'CTANDAQQ309211HYC28LRT4U91': 8,
#  'D317FSLDZG0X0BWKN##NAGHU91': 0,
#  'BCPZQY$DZ4UT0IITDIAPBUFU91': 6,
#  '5YGHO5WZU58S1KUS3JRJ8GFU91': 0,
#  '8$0SEZ9C$VXJ1NX8RG7ML8T7A0': 8,
#  'BKWBD5B7YUV414V2QRMJPIEY90': 7,
#  'W39KVQUMTM3E1CC$FDT11E6U91': 0,
#  'LY$5MORUY8L$0R5ZPVSMNS#T91': 0,
#  'Q77#URGYTV6506VDR7NOG$2U91': 8,
#  '3CQ1WLONGFY316VDR7NOG$2U91': 8,
#  'E175CXUJITBL0NX8RG7ML8T7A0': 3,
#  'XN7WUGUZC1WP0NX8RG7ML8T7A0': 2,
#  'SDCB$2DYS0ED14V2QRMJPIEY90': 7,
#  'X5EAZ50H88PW0NX8RG7ML8T7A0': 2,
#  'S0J5ODGID26904V2QRMJPIEY90': 2,
#  'M#FSEXRA5BH304V2QRMJPIEY90': 2,
#  '8AG89Z9BRP#H0NX8RG7ML8T7A0': 3,
#  'A0S0IMZBBYJ11NX8RG7ML8T7A0': 9,
#  'KI0#F6T5$9811NX8RG7ML8T7A0': 9,
#  'H04YMMUOOJYQ1NX8RG7ML8T7A0': 2,
#  'ET#9KTKEBKHS04V2QRMJPIEY90': 2,
#  'NYT6H2R9#Y6E1NX8RG7ML8T7A0': 2,
#  'DK$SW6LZ8S0T04V2QRMJPIEY90': 6,
#  'XAT1FYTELRRO04V2QRMJPIEY90': 6,
#  'VE8$QBPBL23K0NX8RG7ML8T7A0': 6,
#  'U9SQ46815H6A1NX8RG7ML8T7A0': 0,
#  'E69M2H1X6FZF04V2QRMJPIEY90': 0,
#  'I#PZ8NKDJ86Q04V2QRMJPIEY90': 9,
#  'P714K0OTEFJI0V6EZJ59KGHU91': 9,
#  'I8FC8#EENIQF1R5ZPVSMNS#T91': 8,
#  '$AD27SE#5LG10WY8Y41C3W1U91': 0,
#  '8U00K5FP3Y$S0UV54AM9CPKU91': 8,
#  '9Y5XWJHMJ$X80UV54AM9CPKU91': 9,
#  'GQ2LG9ODJG7L114XGQACHC6U91': 0,
#  '3RNF6W#YNESR13EVNQP90#2U91': 0,
#  '6OS5I2IUE7JO1NX8RG7ML8T7A0': 9,
#  '44B9W8$U0ITS04V2QRMJPIEY90': 2,
#  'G9IZPJ11GCW20NX8RG7ML8T7A0': 2,
#  'QB4PWYQM7B1B04V2QRMJPIEY90': 2,
#  'KLX6P5#GSL$N1NX8RG7ML8T7A0': 6,
#  'JMFANN#L38I41NX8RG7ML8T7A0': 8,
#  'Q9TECKTX3C5K14V2QRMJPIEY90': 0,
#  'QMBODOF8TVSB0NX8RG7ML8T7A0': 4,
#  'SIZM7N57UYR514V2QRMJPIEY90': 2,
#  'NNXV7KOHE0DP14V2QRMJPIEY90': 6,
#  'F2SZR8$KHYV414V2QRMJPIEY90': 2,
#  'Q$ESZTUCERPL04V2QRMJPIEY90': 2,
#  '8N1MSM$YQ6L20NX8RG7ML8T7A0': 6,
#  '#N36EN4T40QH14V2QRMJPIEY90': 4,
#  '6OI3JZX#PB9204V2QRMJPIEY90': 0,
#  'CV7O18AP9O$N1BWKN##NAGHU91': 0,
#  'M02BNWVM5XJH0Q$3UK0GBQ#T91': 0,
#  'A0M$2E4$I6RE0NX8RG7ML8T7A0': 0,
#  '86IHB6N$DY1Z13EVNQP90#2U91': 0,
#  '9I7EWOILXS8Q14V2QRMJPIEY90': 0,
#  'W3$K#XZ0PY4K1JJPFKEE0Z2U91': 0,
#  'GW5LKL7KWEW90V6EZJ59KGHU91': 2,
#  'HL$VE2P583WN16VDR7NOG$2U91': 0,
#  '6K5GV8K6D20N1Q$3UK0GBQ#T91': 7,
#  'HMKFDQ$OCI9V0NX8RG7ML8T7A0': 8,
#  '1LZW$2V0W54O1NX8RG7ML8T7A0': 1,
#  '9IA1#8JQ7L#A16W1HTEMVMEU91': 8,
#  'QSI9M7MIFHD904V2QRMJPIEY90': 0,
#  'J8#JAP8S42N006W1HTEMVMEU91': 2,
#  'DVH0Y2#HDUOH13EVNQP90#2U91': 2,
#  'FBQ2F9P8KQR40SS0YHV2URJU91': 0,
#  'L2V6NDFY9Y4904V2QRMJPIEY90': 2,
#  'GFB9G73B45$A0YATAP92TUEU91': 0,
#  '$GGJ7NMJR95Z0X9JIKKMFPKU91': 0,
#  'KFE3A0SWFM8S1TKF#6P2WYLU91': 9,
#  'WRMEJVD2X0KY03AYHQV9168U91': 6,
#  'WJEZM3#ZCS231UV54AM9CPKU91': 0,
#  '1$KWWP2IQTW304V2QRMJPIEY90': 2,
#  'BROQKVAJA$PL08XJ$X2GZV1U91': 5,
#  'PZYB3$W6FUXP04V2QRMJPIEY90': 6,
#  'JALQUDQP6C1816V2QRMJPIEY90': 0,
#  'X7KJ52WVS#ZG16VDR7NOG$2U91': 4,
#  '$ZHK7TLWD6X201HYC28LRT4U91': 0,
#  'TUHFAWP5DRZ$0#DZEARJDT4U91': 4,
#  'UTB20CW3YJLT0T#K6JVYXMEU91': 0,
#  '9#PXPSS1NB141EQT5KFUBW1U91': 0,
#  'P6HWIBP8FP6806V2QRMJPIEY90': 0,
#  'MQ3F5RDGHDDJ0BWKN##NAGHU91': 2,
#  'FCQ2E$8VAMA10ZG214S$QZ2U91': 8,
#  '6NRT4M9QNAHG1XC9F63XMQ#T91': 8,
#  'D#QTMCHYRMTD0TKF#6P2WYLU91': 4,
#  'R2ZWR5ZWT2W11OKNZBG03LLU91': 4,
#  'TKIX#F4C3CQ41YATAP92TUEU91': 8,
#  ...}

# %% [markdown]
# #### Get information of topics

# %%
def get_topics2(lda):
    'Return topics with terms and probabilities.'
    def get_one(id):
        return [(lda.id2word[t]) for t, p in lda.get_topic_terms(id, topn=5)]

    return [get_one(i) for i in range(lda.num_topics)]

# %%
def get_topics(lda):
    'Return topics with terms and probabilities.'
    def get_one(id):
        return [(lda.id2word[t], float(p)) for t, p in lda.get_topic_terms(id, topn=5)]

    return [get_one(i) for i in range(lda.num_topics)]

# %%
all_topics = get_topics2(lda)
all_topics
# Out:
# [['DisplayOneUser',
#   'CloseTab',
#   'CreateLoginArea',
#   'AddNewLoginArea',
#   'UpdateUserDetails'],
#  ['ChooseOrganization',
#   'FilterByApp',
#   'FilterByAppACL',
#   'DisplayOneUser',
#   'AuthenticationHistorySearch'],
#  ['CloseTab',
#   'DisplayOneAppli',
#   'UnLockUser',
#   'ManageAppRole',
#   'FilterRolesForApp'],
#  ['TpfRefreshTable',
#   'FilterHistory',
#   'TpfMassImport',
#   'CreateAclForRole',
#   'DisplayOneAppli'],
#  ['CreateUser',
#   'WarningDeleteUser',
#   'CloseTab',
#   'DeleteUser',
#   'ResetPwdUnlock'],
#  ['Next', 'Prev', 'DisplayOneUser', 'Cancel', 'OneUserRoleDetails'],
#  ['DisplayOrgaDetails',
#   'AdminOguStep1',
#   'RefreshReports',
#   'AddOfficeDod',
#   'AddOfficeDodFinish'],
#  ['AssignAcl2',
#   'AssignAcl1',
#   'AssignACLStep3',
#   'AssignRoleAclConfirmation1',
#   'SearchRoleForAssignRoleAcl'],
#  ['SearchOffice',
#   'CloseTab',
#   'DisplayOneOffice',
#   'DisplayOneUser',
#   'DisplayOneOGU'],
#  ['AssignRole1',
#   'AssignRole2',
#   'AssignRoleAclConfirmation1',
#   'CloseTab',
#   'CreateUser']]

# %% [markdown]
# #### Export data

# %%
with open(output_file, 'w') as f:
    json.dump({ 'topics': all_topics, 'sessions': output_data }, f)

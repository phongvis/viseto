# %% [markdown]
# # Exporting a collection of LDA models with varying parameter values

# %%
import nlp
import json

# %% [markdown]
# ### Load and clean the data

# %%
data = nlp.load_file('../data/lee.txt')
docs = nlp.preprocess(data)
len(data), data[0], docs[0]
# Out:
# (300,
#  'Hundreds of people have been forced to vacate their homes in the Southern Highlands of New South Wales as strong winds today pushed a huge bushfire towards the town of Hill Top. A new blaze near Goulburn, south-west of Sydney, has forced the closure of the Hume Highway. At about 4:00pm AEDT, a marked deterioration in the weather as a storm cell moved east across the Blue Mountains forced authorities to make a decision to evacuate people from homes in outlying streets at Hill Top in the New South Wales southern highlands. An estimated 500 residents have left their homes for nearby Mittagong. The New South Wales Rural Fire Service says the weather conditions which caused the fire to burn in a finger formation have now eased and about 60 fire units in and around Hill Top are optimistic of defending all properties. As more than 100 blazes burn on New Year\'s Eve in New South Wales, fire crews have been called to new fire at Gunning, south of Goulburn. While few details are available at this stage, fire authorities says it has closed the Hume Highway in both directions. Meanwhile, a new fire in Sydney\'s west is no longer threatening properties in the Cranebrook area. Rain has fallen in some parts of the Illawarra, Sydney, the Hunter Valley and the north coast. But the Bureau of Meteorology\'s Claire Richards says the rain has done little to ease any of the hundred fires still burning across the state. "The falls have been quite isolated in those areas and generally the falls have been less than about five millimetres," she said. "In some places really not significant at all, less than a millimetre, so there hasn\'t been much relief as far as rain is concerned. "In fact, they\'ve probably hampered the efforts of the firefighters more because of the wind gusts that are associated with those thunderstorms."',
#  ['hundred',
#   'people',
#   'forced',
#   'vacate',
#   'home',
#   'southern',
#   'highland',
#   'new',
#   'south',
#   'wale',
#   'strong',
#   'wind',
#   'today',
#   'pushed',
#   'huge',
#   'bushfire',
#   'towards',
#   'town',
#   'hill',
#   'top',
#   'new',
#   'blaze',
#   'near',
#   'goulburn',
#   'southwest',
#   'sydney',
#   'forced',
#   'closure',
#   'hume',
#   'highway',
#   '400pm',
#   'aedt',
#   'marked',
#   'deterioration',
#   'weather',
#   'storm',
#   'cell',
#   'moved',
#   'east',
#   'across',
#   'blue',
#   'mountain',
#   'forced',
#   'authority',
#   'make',
#   'decision',
#   'evacuate',
#   'people',
#   'home',
#   'outlying',
#   'street',
#   'hill',
#   'top',
#   'new',
#   'south',
#   'wale',
#   'southern',
#   'highland',
#   'estimated',
#   '500',
#   'resident',
#   'left',
#   'home',
#   'nearby',
#   'mittagong',
#   'new',
#   'south',
#   'wale',
#   'rural',
#   'fire',
#   'service',
#   'say',
#   'weather',
#   'condition',
#   'caused',
#   'fire',
#   'burn',
#   'finger',
#   'formation',
#   'eased',
#   'fire',
#   'unit',
#   'around',
#   'hill',
#   'top',
#   'optimistic',
#   'defending',
#   'property',
#   '100',
#   'blaze',
#   'burn',
#   'new',
#   'year',
#   'eve',
#   'new',
#   'south',
#   'wale',
#   'fire',
#   'crew',
#   'called',
#   'new',
#   'fire',
#   'gunning',
#   'south',
#   'goulburn',
#   'detail',
#   'available',
#   'stage',
#   'fire',
#   'authority',
#   'say',
#   'closed',
#   'hume',
#   'highway',
#   'direction',
#   'meanwhile',
#   'new',
#   'fire',
#   'sydney',
#   'west',
#   'longer',
#   'threatening',
#   'property',
#   'cranebrook',
#   'area',
#   'rain',
#   'fallen',
#   'part',
#   'illawarra',
#   'sydney',
#   'hunter',
#   'valley',
#   'north',
#   'coast',
#   'bureau',
#   'meteorology',
#   'claire',
#   'richards',
#   'say',
#   'rain',
#   'done',
#   'little',
#   'ease',
#   'hundred',
#   'fire',
#   'still',
#   'burning',
#   'across',
#   'state',
#   'fall',
#   'quite',
#   'isolated',
#   'area',
#   'generally',
#   'fall',
#   'le',
#   'five',
#   'millimetre',
#   'said',
#   'place',
#   'really',
#   'significant',
#   'le',
#   'millimetre',
#   'hasnt',
#   'much',
#   'relief',
#   'far',
#   'rain',
#   'concerned',
#   'fact',
#   'theyve',
#   'probably',
#   'hampered',
#   'effort',
#   'firefighter',
#   'wind',
#   'gust',
#   'associated',
#   'thunderstorm'])

# %% [markdown]
# ### Compute and save models

# %%
alphas = [0.01, 0.1, 1, 10]
betas = [0.01, 0.1, 1, 10]
num_topics = [5, 10, 15, 20]

# %%
corpus, dictionary = nlp.build_corpus_dictionary(docs, min_count=10)
for a in alphas:
    for b in betas:
        for k in num_topics:
            name = '../data/models/lee/{}-{}-{}'.format(a, b, k)
            lda = nlp.build_lda_with_corpus(corpus, dictionary, alpha=a, eta=b, num_topics=k, passes=50)
            lda.save(name)
            print('done', name)
# Out:
# /anaconda3/lib/python3.6/site-packages/gensim/models/ldamodel.py:775: RuntimeWarning: divide by zero encountered in log
#   diff = np.log(self.expElogbeta)
# done ../data/models/lee/0.01-0.01-5
# done ../data/models/lee/0.01-0.01-10
# done ../data/models/lee/0.01-0.01-15
# done ../data/models/lee/0.01-0.01-20
# done ../data/models/lee/0.01-0.1-5
# done ../data/models/lee/0.01-0.1-10
# done ../data/models/lee/0.01-0.1-15
# done ../data/models/lee/0.01-0.1-20
# done ../data/models/lee/0.01-1-5
# done ../data/models/lee/0.01-1-10
# done ../data/models/lee/0.01-1-15
# done ../data/models/lee/0.01-1-20
# done ../data/models/lee/0.01-10-5
# done ../data/models/lee/0.01-10-10
# done ../data/models/lee/0.01-10-15
# done ../data/models/lee/0.01-10-20
# done ../data/models/lee/0.1-0.01-5
# done ../data/models/lee/0.1-0.01-10
# done ../data/models/lee/0.1-0.01-15
# done ../data/models/lee/0.1-0.01-20
# done ../data/models/lee/0.1-0.1-5
# done ../data/models/lee/0.1-0.1-10
# done ../data/models/lee/0.1-0.1-15
# done ../data/models/lee/0.1-0.1-20
# done ../data/models/lee/0.1-1-5
# done ../data/models/lee/0.1-1-10
# done ../data/models/lee/0.1-1-15
# done ../data/models/lee/0.1-1-20
# done ../data/models/lee/0.1-10-5
# done ../data/models/lee/0.1-10-10
# done ../data/models/lee/0.1-10-15
# done ../data/models/lee/0.1-10-20
# done ../data/models/lee/1-0.01-5
# done ../data/models/lee/1-0.01-10
# done ../data/models/lee/1-0.01-15
# done ../data/models/lee/1-0.01-20
# done ../data/models/lee/1-0.1-5
# done ../data/models/lee/1-0.1-10
# done ../data/models/lee/1-0.1-15
# done ../data/models/lee/1-0.1-20
# done ../data/models/lee/1-1-5
# done ../data/models/lee/1-1-10
# done ../data/models/lee/1-1-15
# done ../data/models/lee/1-1-20
# done ../data/models/lee/1-10-5
# done ../data/models/lee/1-10-10
# done ../data/models/lee/1-10-15
# done ../data/models/lee/1-10-20
# done ../data/models/lee/10-0.01-5
# done ../data/models/lee/10-0.01-10
# done ../data/models/lee/10-0.01-15
# done ../data/models/lee/10-0.01-20
# done ../data/models/lee/10-0.1-5
# done ../data/models/lee/10-0.1-10
# done ../data/models/lee/10-0.1-15
# done ../data/models/lee/10-0.1-20
# done ../data/models/lee/10-1-5
# done ../data/models/lee/10-1-10
# done ../data/models/lee/10-1-15
# done ../data/models/lee/10-1-20
# done ../data/models/lee/10-10-5
# done ../data/models/lee/10-10-10
# done ../data/models/lee/10-10-15
# done ../data/models/lee/10-10-20

# %% [markdown]
# ---

# %%
# %load_ext autoreload
# %autoreload 2
